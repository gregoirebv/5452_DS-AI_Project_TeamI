# %% [markdown]
# ### BERT for topic discovery, exploration, visualization (2/2)

# %%
# HuggingFace token for BERTopic

import os

os.environ["HF_TOKEN"] = "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"

# %%
# articles dataset import

import pandas as pd

df1 = pd.read_csv("clean-buzzfeed-v02.csv")
df2 = pd.read_csv("clean-snopes_checked_v02.csv")

# %%
# columns check

df1 = df1.dropna(subset=["ArticleText"])
df2 = df2.dropna(subset=["ArticleText"])

df1 = df1[df1["ArticleText"].str.strip() != ""]
df2 = df2[df2["ArticleText"].str.strip() != ""]

print(df1.columns)
print(df2.columns)
# Out:
# Index(['URL', 'ArticleText'], dtype='str')
# Index(['URL', 'ArticleText'], dtype='str')

# %%
# articles loading check

docs1 = df1["ArticleText"].astype(str).tolist()
docs2 = df2["ArticleText"].astype(str).tolist()

print(f"Dataset 1: {len(docs1)} articles")
print(f"Dataset 2: {len(docs2)} articles")
# Out:
# Dataset 1: 1380 articles
# Dataset 2: 312 articles

# %%
# removing English stop words (the, of, and, to, etc.)

from sklearn.feature_extraction.text import CountVectorizer

vectorizer_model = CountVectorizer(
    stop_words="english",
    ngram_range=(1, 2),
    min_df=2,
    max_df=0.95
)

# %%
# BERTopic on Dataset 1 (Buzzfeed)

from bertopic import BERTopic

topic_model = BERTopic(
    vectorizer_model=vectorizer_model,
    language="english",
    min_topic_size=5,
    calculate_probabilities=False,
    verbose=True
)

topics, probs = topic_model.fit_transform(docs1)
# Out:
# 2026-06-11 21:40:32,190 - BERTopic - Embedding - Transforming documents to embeddings.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Batches:   0%|          | 0/44 [00:00<?, ?it/s]
# 2026-06-11 21:41:18,076 - BERTopic - Embedding - Completed ✓
# 2026-06-11 21:41:18,078 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2026-06-11 21:41:38,790 - BERTopic - Dimensionality - Completed ✓
# 2026-06-11 21:41:38,792 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2026-06-11 21:41:38,877 - BERTopic - Cluster - Completed ✓
# 2026-06-11 21:41:38,884 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2026-06-11 21:41:40,405 - BERTopic - Representation - Completed ✓

# %%
# Discovered topics

topic_info = topic_model.get_topic_info()
print(topic_info.head(20))
# Out:
#     Topic  Count                                             Name  \
# 0      -1    321              -1_debate_clinton_president_hillary
# 1       0     45              0_percent_poll_voters_likely voters
# 2       1     38            1_million_campaign_donors_fundraising
# 3       2     36               2_terrorism_muslim_city_terrorists
# 4       3     30                    3_emails_fbi_email_department
# 5       4     30        4_stopandfrisk_york_new york_hide caption
# 6       5     30                5_clinton_debate_hillary_clintons
# 7       6     28              6_debate_debates_candidates_clinton
# 8       7     28          7_anthem_nascar_national anthem_players
# 9       8     27                   8_students_flag_school_student
# 10      9     26                   9_rahami_jersey_new jersey_new
# 11     10     26          10_police_charlotte_protesters_protests
# 12     11     25                 11_tax_returns_taxes_tax returns
# 13     12     25               12_bush_kennedy_president_families
# 14     13     25                  13_black_king_slavery_community
# 15     14     24                14_birther_born_birth_certificate
# 16     15     23  15_foundation_trump foundation_money_charitable
# 17     16     21                        16_gun_police_scott_video
# 18     17     21                    17_syrian_syria_aleppo_syrias
# 19     18     20                      18_weiner_sexual_girl_child
#
#                                        Representation  \
# 0   [debate, clinton, president, hillary, campaign...
# 1   [percent, poll, voters, likely voters, clinton...
# 2   [million, campaign, donors, fundraising, super...
# 3   [terrorism, muslim, city, terrorists, attacks,...
# 4   [emails, fbi, email, department, state departm...
# 5   [stopandfrisk, york, new york, hide caption, c...
# 6   [clinton, debate, hillary, clintons, hide capt...
# 7   [debate, debates, candidates, clinton, monday,...
# 8   [anthem, nascar, national anthem, players, kae...
# 9   [students, flag, school, student, campus, univ...
# 10  [rahami, jersey, new jersey, new, ahmad, fbi, ...
# 11  [police, charlotte, protesters, protests, offi...
# 12  [tax, returns, taxes, tax returns, reid, estat...
# 13  [bush, kennedy, president, families, george, p...
# 14  [black, king, slavery, community, black commun...
# 15  [birther, born, birth, certificate, birth cert...
# 16  [foundation, trump foundation, money, charitab...
# 17  [gun, police, scott, video, officers, keith, s...
# 18  [syrian, syria, aleppo, syrias, kerry, civil w...
# 19  [weiner, sexual, girl, child, rape, muslim, re...
#
#                                   Representative_Docs
# 0   ["With red lips, blue eyes and big blond hair,...
# 1   ["Democratic presidential candidate Hillary Cl...
# 2   ["MIAMI ? DonaldTrump aides are discussing the...
# 3   ["Michigan has become a hotbed of hate as Musl...
# 4   ["Cheryl Mills, a longtime Clinton aide, recei...
# 5   ["As Donald Trump courted African-American vot...
# 6   ["Hempstead, New York  Hillary Clinton stepped...
# 7   ["The impact of one line zingers can fade afte...
# 8   ["NFL Boycott In FULL EFFECT! 44% Of Americans...
# 9   ["?This Is How I Teach Freedom Of Speech? Flag...
# 10  ["Ahmad Khan Rahami, earlier named a person of...
# 11  ["BREAKING NEWS: Arrest Made In DEATH Of Charl...
# 12  [" The Senate reconvened this week as Democrat...
# 13  ["I was a Democrat all my life. I came to Wash...
# 14  ["Donald Trump has again made a huge mistake w...
# 15  ["Donald Trump's surrogates and leading suppor...
# 16  [" A new investigation has determined that Don...
# 17  ["BREAKING: Charlotte Shooting Footage Has Bee...
# 18  ["Even as U.S. Secretary of State John Kerry h...
# 19  ["Huma Abedin dumped her then-husband Anthony ...

# %%
# Non-outlier topics

for topic_id in topic_info["Topic"][:5]:
    
    if topic_id == -1:
        continue

    print(f"\nTOPIC {topic_id}")
    print(topic_model.get_topic(topic_id))
# Out:
# TOPIC 0
# [('percent', np.float64(0.043064557176801466)), ('poll', np.float64(0.031223029882456593)), ('voters', np.float64(0.02871901715508905)), ('likely voters', np.float64(0.01823676600437102)), ('clinton', np.float64(0.01785008184617098)), ('points', np.float64(0.0177291978676574)), ('likely', np.float64(0.01733236431056457)), ('margin', np.float64(0.015920994436802314)), ('43', np.float64(0.01540544491842321)), ('voting', np.float64(0.014608200275872079))]
#
# TOPIC 1
# [('million', np.float64(0.03877299533130762)), ('campaign', np.float64(0.026187695605396744)), ('donors', np.float64(0.015442983215913692)), ('fundraising', np.float64(0.014722029418442561)), ('super', np.float64(0.014334479539321626)), ('pac', np.float64(0.012879441808430907)), ('ads', np.float64(0.011776029810732863)), ('money', np.float64(0.010433139067530035)), ('republican', np.float64(0.010246433425628835)), ('august', np.float64(0.010157932780444348))]
#
# TOPIC 2
# [('terrorism', np.float64(0.018767084469856015)), ('muslim', np.float64(0.016497282085678567)), ('city', np.float64(0.0151272966611221)), ('terrorists', np.float64(0.012410168448121173)), ('attacks', np.float64(0.01219862556631146)), ('muslims', np.float64(0.011900495831617793)), ('islamic', np.float64(0.01141264991349035)), ('clinton', np.float64(0.01041273973407069)), ('new', np.float64(0.010228520059957516)), ('rhetoric', np.float64(0.009563196235523987))]
#
# TOPIC 3
# [('emails', np.float64(0.041517678665474705)), ('fbi', np.float64(0.031792051779296074)), ('email', np.float64(0.027355207664465756)), ('department', np.float64(0.02625920536622522)), ('state department', np.float64(0.022705024428636825)), ('server', np.float64(0.022327809054749563)), ('investigation', np.float64(0.021498317789208087)), ('state', np.float64(0.021235888471396406)), ('immunity', np.float64(0.02023363555621141)), ('records', np.float64(0.01939348496010754))]

# %%
# Visualization of topics

fig = topic_model.visualize_topics()
fig.show()

# %%
topic_model.visualize_barchart()

# %%
# Compare topics between Dataset 1 and Dataset 2

docs_a = df1["ArticleText"].tolist()
docs_b = df2["ArticleText"].tolist()

all_docs = docs_a + docs_b
sources = (
    ["Dataset_A"] * len(docs_a)
    + ["Dataset_B"] * len(docs_b)
)

topics, probs = topic_model.fit_transform(all_docs)

comparison = pd.DataFrame({
    "source": sources,
    "topic": topics
})

pd.crosstab(
    comparison["topic"],
    comparison["source"]
)
# Out:
# 2026-06-11 21:44:49,135 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/53 [00:00<?, ?it/s]
# 2026-06-11 21:45:37,744 - BERTopic - Embedding - Completed ✓
# 2026-06-11 21:45:37,746 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2026-06-11 21:45:42,174 - BERTopic - Dimensionality - Completed ✓
# 2026-06-11 21:45:42,176 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2026-06-11 21:45:42,255 - BERTopic - Cluster - Completed ✓
# 2026-06-11 21:45:42,262 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2026-06-11 21:45:44,216 - BERTopic - Representation - Completed ✓
# source  Dataset_A  Dataset_B
# topic
# -1            324        124
#  0             46          1
#  1             31          7
#  2             24         12
#  3             30          6
# ...           ...        ...
#  76             6          0
#  77             0          6
#  78             5          1
#  79             5          0
#  80             5          0
#
# [82 rows x 2 columns]

# %%
hierarchical_topics = topic_model.hierarchical_topics(all_docs)

fig2 = topic_model.visualize_hierarchy(
    hierarchical_topics=hierarchical_topics
)
fig2.show()
# Out:
# 100%|██████████| 79/79 [00:00<00:00, 328.64it/s]

# %% [markdown]
# # Conclusion
#
# In this notebook, we:
#
# - Used the previous BERTopic model using our larger dataset and let it discover topics from 'ArticleText' data
# - Visualized outputs with additional native graphic generation capabilities and compared insights across our datasets.
#
# This methodology be be operationalized over time and generalized to offer insights in other important news topics, such as health, politics, technology, etc. present in the loaded datasets.
